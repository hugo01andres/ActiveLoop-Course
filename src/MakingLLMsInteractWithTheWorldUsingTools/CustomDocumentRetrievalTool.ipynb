# %%
import os
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["ACTIVELOOP_TOKEN"] = os.getenv("ACTIVELOOP_TOKEN")

# %%
from langchain.vectorstores import DeepLake
from langchain.embeddings.openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")

# create Deep Lake dataset
# TODO: use your organization id here. (by default, org id is your username)
my_activeloop_org_id = "hugo01andres"
my_activeloop_dataset_name = "langchain_course_custom_tool2"
dataset_path = f"hub://{my_activeloop_org_id}/{my_activeloop_dataset_name}"

# Before executing the following code, make sure to have your
# Activeloop key saved in the “ACTIVELOOP_TOKEN” environment variable.
db = DeepLake(dataset_path=dataset_path, embedding=embeddings)
# add faqs to the dataset
faqs = [
    "What is PayPal?\nPayPal is a digital wallet that follows you wherever you go. Pay any way you want. Link your credit cards to your PayPal Digital wallet, and when you want to pay, simply log in with your username and password and pick which one you want to use.",
    "Why should I use PayPal?\nIt's Fast! We will help you pay in just a few clicks. Enter your email address and password, and you're pretty much done! It's Simple! There's no need to run around searching for your wallet. Better yet, you don't need to type in your financial details again and again when making a purchase online. We make it simple for you to pay with just your email address and password.",
    "Is it secure?\nPayPal is the safer way to pay because we keep your financial information private. It isn't shared with anyone else when you shop, so you don't have to worry about paying businesses and people you don't know. On top of that, we've got your back. If your eligible purchase doesn't arrive or doesn't match its description, we will refund you the full purchase price plus shipping costs with PayPal's Buyer Protection program.",
    "Where can I use PayPal?\nThere are millions of places you can use PayPal worldwide. In addition to online stores, there are many charities that use PayPal to raise money. Find a list of charities you can donate to here. Additionally, you can send funds internationally to anyone almost anywhere in the world with PayPal. All you need is their email address. Sending payments abroad has never been easier.",
    "Do I need a balance in my account to use it?\nYou do not need to have any balance in your account to use PayPal. Similar to a physical wallet, when you are making a purchase, you can choose to pay for your items with any of the credit cards that are attached to your account. There is no need to pre-fund your account."
]
db.add_texts(faqs)

# Get the retriever object from the deep lake db object
retriever = db.as_retriever()
# Out:
# ---------------------------------------------------------------------------
# ResourceNotFoundException                 Traceback (most recent call last)
# Cell In[3], line 14
#      10 dataset_path = f"hub://{my_activeloop_org_id}/{my_activeloop_dataset_name}"
#      12 # Before executing the following code, make sure to have your
#      13 # Activeloop key saved in the “ACTIVELOOP_TOKEN” environment variable.
# ---> 14 db = DeepLake(dataset_path=dataset_path, embedding=embeddings)
#      15 # add faqs to the dataset
#      16 faqs = [
#      17     "What is PayPal?\nPayPal is a digital wallet that follows you wherever you go. Pay any way you want. Link your credit cards to your PayPal Digital wallet, and when you want to pay, simply log in with your username and password and pick which one you want to use.",
#      18     "Why should I use PayPal?\nIt's Fast! We will help you pay in just a few clicks. Enter your email address and password, and you're pretty much done! It's Simple! There's no need to run around searching for your wallet. Better yet, you don't need to type in your financial details again and again when making a purchase online. We make it simple for you to pay with just your email address and password.",
#    (...)
#      21     "Do I need a balance in my account to use it?\nYou do not need to have any balance in your account to use PayPal. Similar to a physical wallet, when you are making a purchase, you can choose to pay for your items with any of the credit cards that are attached to your account. There is no need to pre-fund your account."
#      22 ]
#
# File /workspaces/ActiveLoop-Course/env/lib/python3.10/site-packages/langchain_community/vectorstores/deeplake.py:192, in DeepLake.__init__(self, dataset_path, token, embedding, embedding_function, read_only, ingestion_batch_size, num_workers, verbose, exec_option, runtime, index_params, **kwargs)
#     186 if embedding_function:
#     187     logger.warning(
#     188         "Using embedding function is deprecated and will be removed "
#     189         "in the future. Please use embedding instead."
#     190     )
# --> 192 self.vectorstore = DeepLakeVectorStore(
#     193     path=self.dataset_path,
#     194     embedding_function=embedding_function or embedding,
#     195     read_only=read_only,
#     196     token=token,
#     197     exec_option=exec_option,
#     198     verbose=verbose,
#     199     runtime=runtime,
#     200     index_params=index_params,
#     201     **kwargs,
#     202 )
#     204 self._embedding_function = embedding_function or embedding
#     205 self._id_tensor_name = "ids" if "ids" in self.vectorstore.tensors() else "id"
#
# File /workspaces/ActiveLoop-Course/env/lib/python3.10/site-packages/deeplake/core/vectorstore/deeplake_vectorstore.py:117, in VectorStore.__init__(self, path, dataset, tensor_params, embedding_function, read_only, ingestion_batch_size, index_params, exec_option, token, overwrite, verbose, runtime, creds, org_id, logger, branch, **kwargs)
#      46 """Creates an empty VectorStore or loads an existing one if it exists at the specified ``path``.
#      47
#      48 Examples:
#    (...)
#     112     Setting ``overwrite`` to ``True`` will delete all of your data if the Vector Store exists! Be very careful when setting this parameter.
#     113 """
#     115 kwargs.pop("num_workers", None)
# --> 117 self.dataset_handler = get_dataset_handler(
#     118     path=path,
#     119     dataset=dataset,
#     120     tensor_params=tensor_params,
#     121     embedding_function=embedding_function,
#     122     read_only=read_only,
#     123     ingestion_batch_size=ingestion_batch_size,
#     124     index_params=index_params,
#     125     num_workers=0,
#     126     exec_option=exec_option,
#     127     token=token,
#     128     overwrite=overwrite,
#     129     verbose=verbose,
#     130     runtime=runtime,
#     131     creds=creds,
#     132     org_id=org_id,
#     133     logger=logger,
#     134     branch=branch,
#     135     **kwargs,
#     136 )
#     138 self.deep_memory = DeepMemory(
#     139     dataset=self.dataset_handler.dataset,
#     140     path=self.dataset_handler.path,
#    (...)
#     144     creds=self.dataset_handler.creds,
#     145 )
#
# File /workspaces/ActiveLoop-Course/env/lib/python3.10/site-packages/deeplake/core/vectorstore/dataset_handlers/dataset_handler.py:13, in get_dataset_handler(*args, **kwargs)
#       6 def get_dataset_handler(*args, **kwargs):
#       7     # TODO: Use this logic when managed db will be ready
#       8     # runtime = kwargs.get("runtime", None)
#    (...)
#      11     # else:
#      12     #     return ClientSideDH(*args, **kwargs)
# ---> 13     return ClientSideDH(*args, **kwargs)
#
# File /workspaces/ActiveLoop-Course/env/lib/python3.10/site-packages/deeplake/core/vectorstore/dataset_handlers/client_side_dataset_handler.py:66, in ClientSideDH.__init__(self, path, dataset, tensor_params, embedding_function, read_only, ingestion_batch_size, index_params, num_workers, exec_option, token, overwrite, verbose, runtime, creds, org_id, logger, branch, **kwargs)
#      64 self.index_params = utils.parse_index_params(index_params)
#      65 kwargs["index_params"] = self.index_params
# ---> 66 self.dataset = dataset or dataset_utils.create_or_load_dataset(
#      67     tensor_params=tensor_params,
#      68     dataset_path=self.path,
#      69     token=self.token,
#      70     creds=self.creds,
#      71     logger=self.logger,
#      72     read_only=read_only,
#      73     exec_option=exec_option,
#      74     embedding_function=embedding_function,
#      75     overwrite=overwrite,
#      76     runtime=runtime,
#      77     org_id=self.org_id,
#      78     branch=branch,
#      79     **kwargs,
#      80 )
#      81 self.verbose = verbose
#      82 self.tensor_params = tensor_params
#
# File /workspaces/ActiveLoop-Course/env/lib/python3.10/site-packages/deeplake/core/vectorstore/vector_search/dataset/dataset.py:52, in create_or_load_dataset(tensor_params, dataset_path, token, creds, logger, read_only, exec_option, embedding_function, overwrite, runtime, org_id, branch, **kwargs)
#      46     _INDRA_INSTALLED = False  # pragma: no cover
#      48 utils.check_indra_installation(
#      49     exec_option=exec_option, indra_installed=_INDRA_INSTALLED
#      50 )
# ---> 52 if not overwrite and dataset_exists(dataset_path, token, creds, **kwargs):
#      53     if tensor_params is not None and tensor_params != DEFAULT_VECTORSTORE_TENSORS:
#      54         raise ValueError(
#      55             "Vector Store is not empty. You shouldn't specify tensor_params if you're loading from existing dataset."
#      56         )
#
# File /workspaces/ActiveLoop-Course/env/lib/python3.10/site-packages/deeplake/core/vectorstore/vector_search/dataset/dataset.py:87, in dataset_exists(dataset_path, token, creds, **kwargs)
#      85 def dataset_exists(dataset_path, token, creds, **kwargs):
#      86     return (
# ---> 87         deeplake.exists(dataset_path, token=token, creds=creds)
#      88         and "overwrite" not in kwargs
#      89     )
#
# File /workspaces/ActiveLoop-Course/env/lib/python3.10/site-packages/deeplake/api/dataset.py:354, in dataset.exists(path, creds, token)
#     352     creds = {}
#     353 try:
# --> 354     storage, cache_chain = get_storage_and_cache_chain(
#     355         path=path,
#     356         read_only=True,
#     357         creds=creds,
#     358         token=token,
#     359         memory_cache_size=DEFAULT_MEMORY_CACHE_SIZE,
#     360         local_cache_size=DEFAULT_LOCAL_CACHE_SIZE,
#     361     )
#     362 except TokenPermissionError:
#     363     # Cloud Dataset does not exist
#     364     return False
#
# File /workspaces/ActiveLoop-Course/env/lib/python3.10/site-packages/deeplake/util/storage.py:225, in get_storage_and_cache_chain(path, read_only, creds, token, memory_cache_size, local_cache_size, db_engine)
#     199 def get_storage_and_cache_chain(
#     200     path,
#     201     read_only,
#    (...)
#     206     db_engine=False,
#     207 ):
#     208     """
#     209     Returns storage provider and cache chain for a given path, according to arguments passed.
#     210
#    (...)
#     222         A tuple of the storage provider and the storage chain.
#     223     """
# --> 225     storage = storage_provider_from_path(
#     226         path=path,
#     227         db_engine=db_engine,
#     228         creds=creds,
#     229         read_only=read_only,
#     230         token=token,
#     231     )
#     232     memory_cache_size_bytes = memory_cache_size * MB
#     233     local_cache_size_bytes = local_cache_size * MB
#
# File /workspaces/ActiveLoop-Course/env/lib/python3.10/site-packages/deeplake/util/storage.py:57, in storage_provider_from_path(path, creds, read_only, token, is_hub_path, db_engine)
#      55     creds = {}
#      56 if path.startswith("hub://"):
# ---> 57     storage: StorageProvider = storage_provider_from_hub_path(
#      58         path, read_only, db_engine=db_engine, token=token, creds=creds
#      59     )
#      60 else:
#      61     if path.startswith("s3://"):
#
# File /workspaces/ActiveLoop-Course/env/lib/python3.10/site-packages/deeplake/util/storage.py:152, in storage_provider_from_hub_path(path, read_only, db_engine, token, creds)
#     149 client = DeepLakeBackendClient(token=token)
#     151 mode = None if (read_only is None) else ("r" if read_only else "w")
# --> 152 url, final_creds, mode, expiration, repo = get_dataset_credentials(
#     153     client, org_id, ds_name, mode, db_engine
#     154 )
#     156 is_local = get_path_type(url) == "local"
#     158 # ignore mode returned from backend if underlying storage is local
#
# File /workspaces/ActiveLoop-Course/env/lib/python3.10/site-packages/deeplake/util/storage.py:130, in get_dataset_credentials(client, org_id, ds_name, mode, db_engine)
#     121 def get_dataset_credentials(
#     122     client: DeepLakeBackendClient,
#     123     org_id: str,
#    (...)
#     127 ):
#     128     # this will give the proper url (s3, gcs, etc) and corresponding creds, depending on where the dataset is stored.
#     129     try:
# --> 130         url, final_creds, mode, expiration, repo = client.get_dataset_credentials(
#     131             org_id, ds_name, mode=mode, db_engine={"enabled": db_engine}
#     132         )
#     133     except AgreementNotAcceptedError as e:
#     134         handle_dataset_agreements(client, e.agreements, org_id, ds_name)
#
# File /workspaces/ActiveLoop-Course/env/lib/python3.10/site-packages/deeplake/client/client.py:239, in DeepLakeBackendClient.get_dataset_credentials(self, org_id, ds_name, mode, db_engine, no_cache)
#     237 relative_url = GET_DATASET_CREDENTIALS_SUFFIX.format(org_id, ds_name)
#     238 try:
# --> 239     response = self.request(
#     240         "GET",
#     241         relative_url,
#     242         endpoint=self.endpoint(),
#     243         params={
#     244             "mode": mode,
#     245             "no_cache": no_cache,
#     246             "db_engine": json.dumps(db_engine),
#     247         },
#     248     ).json()
#     249 except Exception as e:
#     250     if isinstance(e, AuthorizationException):
#
# File /workspaces/ActiveLoop-Course/env/lib/python3.10/site-packages/deeplake/client/client.py:156, in DeepLakeBackendClient.request(self, method, relative_url, endpoint, params, data, files, json, headers, timeout)
#     154     status_code = response.status_code
#     155     tries += 1
# --> 156 check_response_status(response)
#     157 return response
#
# File /workspaces/ActiveLoop-Course/env/lib/python3.10/site-packages/deeplake/client/utils.py:65, in check_response_status(response)
#      63 elif response.status_code == 404:
#      64     if message != " ":
# ---> 65         raise ResourceNotFoundException(message)
#      66     raise ResourceNotFoundException
#      67 elif response.status_code == 422:
#
# ResourceNotFoundException: Dataset at path hub://hugo01andres/langchain_course_custom_tool is scheduled for deletion.
